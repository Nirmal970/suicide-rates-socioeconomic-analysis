# %%
import numpy as np
import pandas as pd

# %%
#Extracting the csv files into two dataframes
df=pd.read_csv("data/suicide_rates_1990-2022.csv")
df1=pd.read_csv("data/age_std_suicide_rates_1990-2022.csv")

# %%
#top 10 rows of suicide_rates_1990-2022.csv
df.head(10)
# Out:
#   RegionCode RegionName CountryCode CountryName  Year   Sex     AgeGroup  \
# 0         EU     Europe         ALB     Albania  1992  Male   0-14 years
# 1         EU     Europe         ALB     Albania  1992  Male   0-14 years
# 2         EU     Europe         ALB     Albania  1992  Male   0-14 years
# 3         EU     Europe         ALB     Albania  1992  Male   0-14 years
# 4         EU     Europe         ALB     Albania  1992  Male  15-24 years
# 5         EU     Europe         ALB     Albania  1992  Male  15-24 years
# 6         EU     Europe         ALB     Albania  1992  Male  25-34 years
# 7         EU     Europe         ALB     Albania  1992  Male  25-34 years
# 8         EU     Europe         ALB     Albania  1992  Male  35-54 years
# 9         EU     Europe         ALB     Albania  1992  Male  35-54 years
#
#          Generation  SuicideCount  CauseSpecificDeathPercentage  \
# 0  Generation Alpha           0.0                      0.000000
# ...

# %%
#Top 10 rows of age_std_suicide_rates_1990-2022.csv
df1.head(10)
# Out:
#   RegionCode RegionName CountryCode CountryName  Year     Sex  SuicideCount  \
# 0         EU     Europe         ALB     Albania  1992    Male            33
# 1         EU     Europe         ALB     Albania  1992  Female            14
# 2         EU     Europe         ALB     Albania  1993    Male            46
# 3         EU     Europe         ALB     Albania  1993  Female            27
# 4         EU     Europe         ALB     Albania  1994    Male            37
# 5         EU     Europe         ALB     Albania  1994  Female            15
# 6         EU     Europe         ALB     Albania  1995    Male            57
# 7         EU     Europe         ALB     Albania  1995  Female            34
# 8         EU     Europe         ALB     Albania  1996    Male            53
# 9         EU     Europe         ALB     Albania  1996  Female            39
#
#    CauseSpecificDeathPercentage  StdDeathRate  DeathRatePer100K  Population  \
# ...

# %% [markdown]
# Data cleaning and transformations for Dataframe df

# %%
#printing the schema of dataframe df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118560 entries, 0 to 118559
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   RegionCode                    118560 non-null  object
#  1   RegionName                    118560 non-null  object
#  2   CountryCode                   118560 non-null  object
#  3   CountryName                   118560 non-null  object
#  4   Year                          118560 non-null  int64
#  5   Sex                           118560 non-null  object
#  6   AgeGroup                      118560 non-null  object
#  7   Generation                    118560 non-null  object
#  8   SuicideCount                  118096 non-null  float64
#  9   CauseSpecificDeathPercentage  114271 non-null  float64
#  10  DeathRatePer100K              107896 non-null  float64
#  11  Population                    112640 non-null  float64
# ...

# %%
print("Total number of Null values by each column")
print(df.isnull().sum())
# Out:
# Total number of Null values by each column
# RegionCode                          0
# RegionName                          0
# CountryCode                         0
# CountryName                         0
# Year                                0
# Sex                                 0
# AgeGroup                            0
# Generation                          0
# SuicideCount                      464
# CauseSpecificDeathPercentage     4289
# DeathRatePer100K                10664
# Population                       5920
# GDP                              7240
# GDPPerCapita                     7240
# GrossNationalIncome              9960
# GNIPerCapita                    10760
# InflationRate                   14460
# EmploymentPopulationRatio       11120
# dtype: int64

# %%
df.drop("Generation",axis=1,inplace=True)

# %%
print("Total number of rows for dataframe df",len(df))
# Out:
# Total number of rows for dataframe df 118560

# %%
df.dropna(inplace=True)  #Dropping Null values of dataframe df to enhance data integrity which can produce accurate results during analysis
print("Total number of rows for dataframe df after dropping null values",len(df))
# Out:
# Total number of rows for dataframe df after dropping null values 89000

# %%
df.isnull().sum()
# Out:
# RegionCode                      0
# RegionName                      0
# CountryCode                     0
# CountryName                     0
# Year                            0
# Sex                             0
# AgeGroup                        0
# SuicideCount                    0
# CauseSpecificDeathPercentage    0
# DeathRatePer100K                0
# Population                      0
# GDP                             0
# GDPPerCapita                    0
# GrossNationalIncome             0
# GNIPerCapita                    0
# InflationRate                   0
# EmploymentPopulationRatio       0
# dtype: int64

# %%
print("Total number of duplicates in dataframe df",df.duplicated().sum())
# Out:
# Total number of duplicates in dataframe df 15778

# %%
df.drop_duplicates(inplace=True) #Dropping duplicate rows
print("Total number of rows for dataframe df after dropping duplicates values",len(df))
# Out:
# Total number of rows for dataframe df after dropping duplicates values 73222

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data cleaning and trasnformations for dataframe df1

# %%
df1.info()  #Schema for Dataframe df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5928 entries, 0 to 5927
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   RegionCode                    5928 non-null   object
#  1   RegionName                    5928 non-null   object
#  2   CountryCode                   5928 non-null   object
#  3   CountryName                   5928 non-null   object
#  4   Year                          5928 non-null   int64
#  5   Sex                           5928 non-null   object
#  6   SuicideCount                  5928 non-null   int64
#  7   CauseSpecificDeathPercentage  5927 non-null   float64
#  8   StdDeathRate                  5720 non-null   float64
#  9   DeathRatePer100K              5720 non-null   float64
#  10  Population                    5632 non-null   float64
#  11  GDP                           5566 non-null   float64
# ...

# %%
print("Total number of Null values by each column")
print(df1.isnull().sum())
# Out:
# Total number of Null values by each column
# RegionCode                        0
# RegionName                        0
# CountryCode                       0
# CountryName                       0
# Year                              0
# Sex                               0
# SuicideCount                      0
# CauseSpecificDeathPercentage      1
# StdDeathRate                    208
# DeathRatePer100K                208
# Population                      296
# GDP                             362
# GDPPerCapita                    362
# GNI                             498
# GNIPerCapita                    538
# InflationRate                   723
# EmploymentPopulationRatio       556
# dtype: int64

# %%
print("Total number of rows for dataframe df1",len(df1))
# Out:
# Total number of rows for dataframe df1 5928

# %%
df1.drop("EmploymentPopulationRatio",axis=1,inplace=True) #Dropping EmployementPopulationRatio as it has more null values and can produce inaccurate results

# %%
df1.dropna(inplace=True)  #Dropping Null values of dataframe df to enhance data integrity which can produce accurate results during analysis
print("Total number of rows for dataframe df1 after dropping null values",len(df1))
# Out:
# Total number of rows for dataframe df1 after dropping null values 4836

# %%
df1.isnull().sum()
# Out:
# RegionCode                      0
# RegionName                      0
# CountryCode                     0
# CountryName                     0
# Year                            0
# Sex                             0
# SuicideCount                    0
# CauseSpecificDeathPercentage    0
# StdDeathRate                    0
# DeathRatePer100K                0
# Population                      0
# GDP                             0
# GDPPerCapita                    0
# GNI                             0
# GNIPerCapita                    0
# InflationRate                   0
# dtype: int64

# %%
print("Total number of duplicates in dataframe df1",df1.duplicated().sum()) #No duplicated rows found so no need to drop any more values
# Out:
# Total number of duplicates in dataframe df1 0

# %% [markdown]
# Saving the transformed datasets into csv files

# %%
df.to_csv("data/suicide_rates_1990-2022_transformed.csv",index=False)
df1.to_csv("data/age_std_suicide_rates_1990-2022_transformed.csv",index=False)
